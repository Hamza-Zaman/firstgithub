# %%
# body mass index (BMI)
# input Weight
# Height
# BMI (Ask yourself your height)
# Weight
# Calculate BMI
# print BMI (My name is ....., snd my BMI is .....)

# %%
# Weight in kg/height in m and its square

# %%
height= input("What is your height? ") #in meters
# Out:
# What is your height? 1.8288

# %%
height = float(height)
type(height)
# Out:
# float

# %%
weight= input("What is your weight? ") # in kg
# Out:
# What is your weight? 84

# %%
weight = float(weight)
type(weight)
# Out:
# float

# %%
name = input("What is your name? ")
# Out:
# What is your name? Hamza

# %%
BMI = weight/height**2
BMI
# Out:
# 25.115790972322685

# %%
print("My name is", name, "and my BMI is", BMI)
# Out:
# My name is Hamza and my BMI is 25.115790972322685

# %% [markdown]
# # - Categorical Variables
# - Barplot
# - Countplot

# %%
# Seaborn library (bar plot)
import seaborn as sns
import matplotlib.pyplot as plt #seaborn is built on top of matplot lib
sns.set_theme(style="ticks", color_codes=True)

titanic = sns.load_dataset("titanic")
sns.catplot(x="sex", y="survived", hue="class", kind="bar", data=titanic)
plt.show()

# %%
#count plot
import seaborn as sns
import matplotlib.pyplot as plt #seaborn is built on top of matplot lib
sns.set_theme(style="ticks", color_codes=True)

titanic = sns.load_dataset("titanic")
p1= sns.countplot(x="sex", hue="class", data=titanic)
p1.set_title("Plot for Counting")
plt.show()

# %% [markdown]
# # - Continuous Variables
# - Scatterplot

# %%
#scatterplot
import seaborn as sns
import matplotlib.pyplot as plt #seaborn is built on top of matplot lib
sns.set_theme(style="ticks", color_codes=True)

titanic = sns.load_dataset("titanic")
g= sns.FacetGrid(titanic, row="sex", hue="alone")
g= (g.map(plt.scatter, "age", "fare").add_legend())
plt.show()
